# %% [markdown]
# # 3. ANÁLISIS PREDICTIVO.

# %% [markdown]
# ## 3.1 ¿Cuáles son las zonas donde es más probable coger un taxi en función de la hora del día?

# %% [markdown]
# **1. Instalar librerías**

# %%
# !pip install dask
# !pip install folium
# !pip install xgboost
# !pip install gpxpy
# Out:
# Requirement already satisfied: dask in d:\anaconda\lib\site-packages (1.0.0)
# Requirement already satisfied: folium in d:\anaconda\lib\site-packages (0.8.3)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from folium) (2.21.0)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from folium) (1.12.0)
# Requirement already satisfied: branca>=0.3.0 in d:\anaconda\lib\site-packages (from folium) (0.3.1)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from folium) (1.15.4)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from folium) (2.10)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\anaconda\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\anaconda\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->folium) (2019.3.9)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda\lib\site-packages (from jinja2->folium) (1.1.0)
# Requirement already satisfied: xgboost in d:\anaconda\lib\site-packages (0.82)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from xgboost) (1.15.4)
# Requirement already satisfied: scipy in d:\anaconda\lib\site-packages (from xgboost) (1.1.0)
# Requirement already satisfied: gpxpy in d:\anaconda\lib\site-packages (1.3.5)

# %% [markdown]
# **2. Importar librerías**
#
#   -  Se usan librerías tales como dask.dataframe las cuáles permiten el tratamiento de datasets grandes. Esta librería en concreto almacena a trozos en memoria.
#
#   - Se importan librerías tales como random forest para su posterior uso en diferentes apartados de esta misma práctica.

# %%
import dask.dataframe as dd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import folium
import gpxpy.geo
from datetime import datetime
import time
import seaborn as sns
import os
import math
import matplotlib
matplotlib.use('nbagg')

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.cluster import MiniBatchKMeans, KMeans
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# **3. Leer los datos**
#
#   -  Se leen los datos correspondientes (green o yellow). En el caso de Green se dispone de un dataset de menor tamaño que el de Yellow. Es por eso que el Yellow tarda más tiempo en cargarse, debido al uso de la librería anteriormente mencionada, este tiempo se reduce considerablemente.

# %%
dy3 = dd.read_csv("C:/MBD/datos/yellow_tripdata_2015-03.csv")

# %% [markdown]
# **4. Primer visualización de los datos**

# %%
dy3.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2015-03-06 08:02:31   2015-03-06 08:09:55                1
# 1         1  2015-03-06 08:02:31   2015-03-06 08:15:23                1
# 2         1  2015-03-06 08:02:31   2015-03-06 08:12:27                1
# 3         1  2015-03-06 08:02:31   2015-03-06 08:09:09                1
# 4         1  2015-03-06 08:02:32   2015-03-06 08:19:37                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0            1.2        -73.990211        40.750969           1
# 1            3.2        -73.935188        40.800720           1
# 2            1.1        -73.963753        40.767937           1
# 3            0.8        -73.997177        40.742168           1
# 4            2.7        -74.006844        40.730267           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.987892         40.738037             2
# 1                  N         -73.952553         40.765373             2
# 2                  N         -73.956947         40.780270             2
# 3                  N         -74.008064         40.739281             1
# 4                  N         -73.976860         40.750671             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          7.0    0.0      0.5        0.00           0.0
# 1         11.5    0.0      0.5        0.00           0.0
# 2          8.0    0.0      0.5        0.00           0.0
# 3          6.0    0.0      0.5        1.00           0.0
# 4         13.0    0.0      0.5        2.75           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3          7.80
# 1                    0.3         12.30
# 2                    0.3          8.80
# 3                    0.3          7.80
# 4                    0.3         16.55

# %% [markdown]
# **5. Descripción de las variables**

# %% [markdown]
# ![yellow.PNG](attachment:yellow.PNG)

# %% [markdown]
# **6. Se hace una búsqueda de valores nulos dentro del dataset, de haberlos estos serían eliminados del mismo**

# %%
print("Número de valores nulos = {}".format(dy3.isnull().sum().compute()))
# Out:
# Número de valores nulos = VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# pickup_longitude         0
# pickup_latitude          0
# RateCodeID               0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %% [markdown]
# **7. Detectar pickups fuera de NYC**
#
#
#
# > 7.1   Se saben las coordenadas las cuales reprensentan los limites de NYC
#
# > 7.2   Se establecen dichas coordenadas como límite, dejando expuestos esos puntos los cuales no cumplen el requisitondented block

# %%
fuera_de_NYC = dy3[((dy3.pickup_latitude <= 40.5774) | (dy3.pickup_longitude <= -74.15) | (dy3.pickup_latitude >= 40.9176) | (dy3.pickup_longitude >= -73.7004))]

m = folium.Map(location = [40.5774, -73.7004], tiles = "OpenStreetMap")

pickups_fuera = fuera_de_NYC.head(25000)

for i,j in pickups_fuera.iterrows():
    if j["pickup_latitude"] != 0:
        folium.Marker([j["pickup_latitude"], j["pickup_longitude"]]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **8. Detectar dropoffs fuera de NYC**
#
#
#
# > 8.1   Se saben las coordenadas las cuales reprensentan los limites de NYC
#
# > 8.2   Se establecen dichas coordenadas como límite, dejando expuestos esos puntos los cuales no cumplen el requisitondented block

# %%
fuera_de_NYC = dy3[((dy3.dropoff_latitude <= 40.5774) | (dy3.dropoff_longitude <= -74.15) | (dy3.dropoff_latitude >= 40.9176) | (dy3.dropoff_longitude >= -73.7004))]

m = folium.Map(location = [40.5774, -73.7004], tiles = "OpenStreetMap")

dropoff_fuera = fuera_de_NYC.head(25000)

for i,j in dropoff_fuera.iterrows():
    if j["dropoff_latitude"] != 0:
        folium.Marker([j["dropoff_latitude"], j["dropoff_longitude"]]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **9. A lo largo del código se ejecuta la visualización de los datos, con tal de hacer más accesible el nombre de las variables**

# %%
dy3.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2015-03-06 08:02:31   2015-03-06 08:09:55                1
# 1         1  2015-03-06 08:02:31   2015-03-06 08:15:23                1
# 2         1  2015-03-06 08:02:31   2015-03-06 08:12:27                1
# 3         1  2015-03-06 08:02:31   2015-03-06 08:09:09                1
# 4         1  2015-03-06 08:02:32   2015-03-06 08:19:37                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0            1.2        -73.990211        40.750969           1
# 1            3.2        -73.935188        40.800720           1
# 2            1.1        -73.963753        40.767937           1
# 3            0.8        -73.997177        40.742168           1
# 4            2.7        -74.006844        40.730267           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.987892         40.738037             2
# 1                  N         -73.952553         40.765373             2
# 2                  N         -73.956947         40.780270             2
# 3                  N         -74.008064         40.739281             1
# 4                  N         -73.976860         40.750671             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          7.0    0.0      0.5        0.00           0.0
# 1         11.5    0.0      0.5        0.00           0.0
# 2          8.0    0.0      0.5        0.00           0.0
# 3          6.0    0.0      0.5        1.00           0.0
# 4         13.0    0.0      0.5        2.75           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3          7.80
# 1                    0.3         12.30
# 2                    0.3          8.80
# 3                    0.3          7.80
# 4                    0.3         16.55

# %% [markdown]
# **10. En este apartado, se realizan dos funciones.**
#
# > 10.1 La primera de ellas realiza una transformación sobre la variable de tipo tiempo convirtiendo esta en un String.
#
# > 10.2 Se define una función para tener la duración del viaje, el tiempo de pickup y la velocidad.

# %%
def timeToUnix(t):
    change = datetime.strptime(t, "%Y-%m-%d %H:%M:%S") 
    t_tuple = change.timetuple() 
    return time.mktime(t_tuple) + 3600  

def dfWithTripTimes(df):
    startTime = datetime.now()
    duracion = df[["tpep_pickup_datetime", "tpep_dropoff_datetime"]].compute()
    pickup_time = [timeToUnix(pkup) for pkup in duracion["tpep_pickup_datetime"].values]
    dropoff_time = [timeToUnix(drpof) for drpof in duracion["tpep_dropoff_datetime"].values]

    Duracion_viaje = (np.array(dropoff_time) - np.array(pickup_time))/float(60)  
    
    dy3_new = df[['passenger_count','trip_distance','pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude','total_amount']].compute()
    dy3_new["Duracion_viaje"] = Duracion_viaje
    dy3_new["pickup_time"] = pickup_time
    dy3_new["Velocidad"] = (dy3_new["trip_distance"]/dy3_new["Duracion_viaje"])*60  #millas/hr

    return dy3_new

# %% [markdown]
# **11. Se crea un nuevo dataset, el cual contendrá las variables indicadas en la función del código anterior**

# %%
dy3_new = dfWithTripTimes(dy3)

# %%
dy3_new.head()
# Out:
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                1            1.2        -73.990211        40.750969
# 1                1            3.2        -73.935188        40.800720
# 2                1            1.1        -73.963753        40.767937
# 3                1            0.8        -73.997177        40.742168
# 4                1            2.7        -74.006844        40.730267
#
#    dropoff_longitude  dropoff_latitude  total_amount  Duracion_viaje  \
# 0         -73.987892         40.738037          7.80        7.400000
# 1         -73.952553         40.765373         12.30       12.866667
# 2         -73.956947         40.780270          8.80        9.933333
# 3         -74.008064         40.739281          7.80        6.633333
# 4         -73.976860         40.750671         16.55       17.083333
#
#     pickup_time  Velocidad
# 0  1.425629e+09   9.729730
# 1  1.425629e+09  14.922280
# 2  1.425629e+09   6.644295
# 3  1.425629e+09   7.236181
# 4  1.425629e+09   9.482927

# %% [markdown]
# **12. Plot con la librería seaborn, de la duración del viaje. Esto nos sirve para una primera inspección de los valores.**

# %%
plt.figure(figsize = (10,6))
sns.boxplot("Duracion_viaje", data = dy3_new, orient = "v")
plt.tick_params(labelsize = 20)
plt.ylabel("Duracion viaje(minutos)", fontsize = 20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="718.8889079329414">

# %% [markdown]
# **13. Definimos una variable con el fin de  mostrar los valores contenido en los cuántiles.**

# %%
quantile_Duracion_viaje = dy3_new.Duracion_viaje.quantile(np.round(np.arange(0.00, 1.01, 0.01), 2))

# %% [markdown]
# **14. Cuántiles de la duración del viaje. Se observa que no hay tiempos negativos y que el percentil 100 es demasiado mayor para ser real.**

# %%
qValues = np.round(np.arange(0.01, 1.01, 0.01), 2)
for i in qValues:
    print("{} Valor del percentil de la duracion del viaje: {}min".format((int(i*100)), quantile_Duracion_viaje[i]))
# Out:
# 1 Valor del percentil de la duracion del viaje: 1.1666666666666667min
# 2 Valor del percentil de la duracion del viaje: 1.9166666666666667min
# 3 Valor del percentil de la duracion del viaje: 2.35min
# 4 Valor del percentil de la duracion del viaje: 2.683333333333333min
# 5 Valor del percentil de la duracion del viaje: 2.95min
# 6 Valor del percentil de la duracion del viaje: 3.2min
# 7 Valor del percentil de la duracion del viaje: 3.433333333333333min
# 8 Valor del percentil de la duracion del viaje: 3.6333333333333333min
# 9 Valor del percentil de la duracion del viaje: 3.8500000000000005min
# 10 Valor del percentil de la duracion del viaje: 4.033333333333333min
# 11 Valor del percentil de la duracion del viaje: 4.216666666666667min
# 12 Valor del percentil de la duracion del viaje: 4.4min
# 13 Valor del percentil de la duracion del viaje: 4.583333333333333min
# 14 Valor del percentil de la duracion del viaje: 4.75min
# 15 Valor del percentil de la duracion del viaje: 4.916666666666667min
# 16 Valor del percentil de la duracion del viaje: 5.083333333333333min
# 17 Valor del percentil de la duracion del viaje: 5.25min
# 18 Valor del percentil de la duracion del viaje: 5.416666666666667min
# 19 Valor del percentil de la duracion del viaje: 5.583333333333333min
# 20 Valor del percentil de la duracion del viaje: 5.75min
# 21 Valor del percentil de la duracion del viaje: 5.916666666666667min
# 22 Valor del percentil de la duracion del viaje: 6.066666666666666min
# 23 Valor del percentil de la duracion del viaje: 6.233333333333333min
# 24 Valor del percentil de la duracion del viaje: 6.4min
# 25 Valor del percentil de la duracion del viaje: 6.55min
# 26 Valor del percentil de la duracion del viaje: 6.716666666666667min
# 27 Valor del percentil de la duracion del viaje: 6.866666666666666min
# 28 Valor del percentil de la duracion del viaje: 7.033333333333333min
# 28 Valor del percentil de la duracion del viaje: 7.200000000000001min
# 30 Valor del percentil de la duracion del viaje: 7.366666666666666min
# 31 Valor del percentil de la duracion del viaje: 7.516666666666667min
# 32 Valor del percentil de la duracion del viaje: 7.683333333333334min
# 33 Valor del percentil de la duracion del viaje: 7.85min
# 34 Valor del percentil de la duracion del viaje: 8.016666666666667min
# 35 Valor del percentil de la duracion del viaje: 8.183333333333334min
# 36 Valor del percentil de la duracion del viaje: 8.35min
# 37 Valor del percentil de la duracion del viaje: 8.516666666666667min
# 38 Valor del percentil de la duracion del viaje: 8.7min
# 39 Valor del percentil de la duracion del viaje: 8.866666666666667min
# 40 Valor del percentil de la duracion del viaje: 9.033333333333333min
# 41 Valor del percentil de la duracion del viaje: 9.216666666666667min
# 42 Valor del percentil de la duracion del viaje: 9.4min
# 43 Valor del percentil de la duracion del viaje: 9.583333333333334min
# 44 Valor del percentil de la duracion del viaje: 9.75min
# 45 Valor del percentil de la duracion del viaje: 9.95min
# 46 Valor del percentil de la duracion del viaje: 10.133333333333333min
# 47 Valor del percentil de la duracion del viaje: 10.316666666666666min
# 48 Valor del percentil de la duracion del viaje: 10.516666666666667min
# 49 Valor del percentil de la duracion del viaje: 10.7min
# 50 Valor del percentil de la duracion del viaje: 10.9min
# 51 Valor del percentil de la duracion del viaje: 11.1min
# 52 Valor del percentil de la duracion del viaje: 11.316666666666666min
# 53 Valor del percentil de la duracion del viaje: 11.516666666666666min
# 54 Valor del percentil de la duracion del viaje: 11.733333333333333min
# 55 Valor del percentil de la duracion del viaje: 11.95min
# 56 Valor del percentil de la duracion del viaje: 12.166666666666666min
# 56 Valor del percentil de la duracion del viaje: 12.4min
# 57 Valor del percentil de la duracion del viaje: 12.633333333333333min
# 59 Valor del percentil de la duracion del viaje: 12.866666666666667min
# 60 Valor del percentil de la duracion del viaje: 13.1min
# 61 Valor del percentil de la duracion del viaje: 13.35min
# 62 Valor del percentil de la duracion del viaje: 13.6min
# 63 Valor del percentil de la duracion del viaje: 13.866666666666667min
# 64 Valor del percentil de la duracion del viaje: 14.133333333333333min
# 65 Valor del percentil de la duracion del viaje: 14.4min
# 66 Valor del percentil de la duracion del viaje: 14.683333333333334min
# 67 Valor del percentil de la duracion del viaje: 14.966666666666665min
# 68 Valor del percentil de la duracion del viaje: 15.266666666666667min
# 69 Valor del percentil de la duracion del viaje: 15.566666666666666min
# 70 Valor del percentil de la duracion del viaje: 15.883333333333333min
# 71 Valor del percentil de la duracion del viaje: 16.2min
# 72 Valor del percentil de la duracion del viaje: 16.533333333333335min
# 73 Valor del percentil de la duracion del viaje: 16.883333333333333min
# 74 Valor del percentil de la duracion del viaje: 17.25min
# 75 Valor del percentil de la duracion del viaje: 17.633333333333333min
# 76 Valor del percentil de la duracion del viaje: 18.016666666666666min
# 77 Valor del percentil de la duracion del viaje: 18.433333333333334min
# 78 Valor del percentil de la duracion del viaje: 18.85min
# 79 Valor del percentil de la duracion del viaje: 19.3min
# 80 Valor del percentil de la duracion del viaje: 19.766666666666666min
# 81 Valor del percentil de la duracion del viaje: 20.266666666666666min
# 82 Valor del percentil de la duracion del viaje: 20.783333333333335min
# 83 Valor del percentil de la duracion del viaje: 21.333333333333332min
# 84 Valor del percentil de la duracion del viaje: 21.933333333333334min
# 85 Valor del percentil de la duracion del viaje: 22.55min
# 86 Valor del percentil de la duracion del viaje: 23.233333333333334min
# 87 Valor del percentil de la duracion del viaje: 23.966666666666665min
# 88 Valor del percentil de la duracion del viaje: 24.75min
# 89 Valor del percentil de la duracion del viaje: 25.616666666666667min
# 90 Valor del percentil de la duracion del viaje: 26.58333333333333min
# 91 Valor del percentil de la duracion del viaje: 27.65min
# 92 Valor del percentil de la duracion del viaje: 28.883333333333333min
# 93 Valor del percentil de la duracion del viaje: 30.3min
# 94 Valor del percentil de la duracion del viaje: 31.983333333333334min
# 95 Valor del percentil de la duracion del viaje: 34.06666666666667min
# 96 Valor del percentil de la duracion del viaje: 36.766666666666666min
# 97 Valor del percentil de la duracion del viaje: 40.43333333333333min
# 98 Valor del percentil de la duracion del viaje: 45.96666666666667min
# 99 Valor del percentil de la duracion del viaje: 56.016666666666666min
# 100 Valor del percentil de la duracion del viaje: 320006.73333333334min

# %% [markdown]
# **15. Dentro del dataset, se aplica un filtro según lo analizado anteriormente**

# %%
dy3_new = dy3_new[(dy3_new.Duracion_viaje>3) & (dy3_new.Duracion_viaje<720)]

# %% [markdown]
# **16. Plot para ver el cambio una vez realizado el filtro**

# %%
plt.figure(figsize = (10,6))
sns.boxplot("Duracion_viaje", data = dy3_new, orient = "v")
plt.ylim(ymin = 1, ymax = 750)
plt.tick_params(labelsize = 20)
plt.ylabel("Duracion viaje (minutos)", fontsize = 20)
plt.show()
# Out:
# <div id='c9a77e9e-d6de-47e7-9a57-6789375b25ad'></div>

# %% [markdown]
# **17. Con esta visualización se aprecia la distribución de la duración del viaje. La gran mayoría de ellos no supera los 100 minutos.**

# %%
plt.figure(figsize = (12,8))
sns.kdeplot(dy3_new["Duracion_viaje"].values, shade = True, cumulative = False)
plt.tick_params(labelsize = 20)
plt.xlabel("Duracion viaje", fontsize = 20)
plt.title("Distribución de la Duracion del viaje", fontsize = 20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="863.3333562038569">

# %%
dy3_new.head()
# Out:
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                1            1.2        -73.990211        40.750969
# 1                1            3.2        -73.935188        40.800720
# 2                1            1.1        -73.963753        40.767937
# 3                1            0.8        -73.997177        40.742168
# 4                1            2.7        -74.006844        40.730267
#
#    dropoff_longitude  dropoff_latitude  total_amount  Duracion_viaje  \
# 0         -73.987892         40.738037          7.80        7.400000
# 1         -73.952553         40.765373         12.30       12.866667
# 2         -73.956947         40.780270          8.80        9.933333
# 3         -74.008064         40.739281          7.80        6.633333
# 4         -73.976860         40.750671         16.55       17.083333
#
#     pickup_time  Velocidad
# 0  1.425629e+09   9.729730
# 1  1.425629e+09  14.922280
# 2  1.425629e+09   6.644295
# 3  1.425629e+09   7.236181
# 4  1.425629e+09   9.482927

# %% [markdown]
# **18. Definimos una variable con el fin de  mostrar los valores contenido en los cuántiles.**

# %%
quantile_Velocidad = dy3_new.Velocidad.quantile(np.round(np.arange(0.00, 1.01, 0.01), 2))

# %% [markdown]
# **19. Cuántiles de la velocidad del taxi durante el viaje. Se observa que no hay velocidades negativas y que el percentil 100 es demasiado mayor para ser real.**

# %%
qValues = np.round(np.arange(0.01, 1.01, 0.01), 2)
for i in qValues:
    print("{} Valor del percentil de la velocidad del viaje: {}millas/h".format((int(i*100)), quantile_Velocidad[i]))
# Out:
# 1 Valor del percentil de la velocidad del viaje: 3.1304347826086953millas/h
# 2 Valor del percentil de la velocidad del viaje: 3.7344398340248963millas/h
# 3 Valor del percentil de la velocidad del viaje: 4.137931034482759millas/h
# 4 Valor del percentil de la velocidad del viaje: 4.460176991150443millas/h
# 5 Valor del percentil de la velocidad del viaje: 4.73037542662116millas/h
# 6 Valor del percentil de la velocidad del viaje: 4.968152866242039millas/h
# 7 Valor del percentil de la velocidad del viaje: 5.182341650671785millas/h
# 8 Valor del percentil de la velocidad del viaje: 5.381165919282511millas/h
# 9 Valor del percentil de la velocidad del viaje: 5.564068692206076millas/h
# 10 Valor del percentil de la velocidad del viaje: 5.736263736263736millas/h
# 11 Valor del percentil de la velocidad del viaje: 5.9016393442622945millas/h
# 12 Valor del percentil de la velocidad del viaje: 6.055890410958903millas/h
# 13 Valor del percentil de la velocidad del viaje: 6.206896551724138millas/h
# 14 Valor del percentil de la velocidad del viaje: 6.350067842605156millas/h
# 15 Valor del percentil de la velocidad del viaje: 6.489195278291762millas/h
# 16 Valor del percentil de la velocidad del viaje: 6.625766871165643millas/h
# 17 Valor del percentil de la velocidad del viaje: 6.756164383561645millas/h
# 18 Valor del percentil de la velocidad del viaje: 6.885245901639345millas/h
# 19 Valor del percentil de la velocidad del viaje: 7.009194159004868millas/h
# 20 Valor del percentil de la velocidad del viaje: 7.130247578040905millas/h
# 21 Valor del percentil de la velocidad del viaje: 7.2507552870090635millas/h
# 22 Valor del percentil de la velocidad del viaje: 7.368821292775665millas/h
# 23 Valor del percentil de la velocidad del viaje: 7.484745762711865millas/h
# 24 Valor del percentil de la velocidad del viaje: 7.598944591029024millas/h
# 25 Valor del percentil de la velocidad del viaje: 7.71178188899708millas/h
# 26 Valor del percentil de la velocidad del viaje: 7.826086956521739millas/h
# 27 Valor del percentil de la velocidad del viaje: 7.933422103861518millas/h
# 28 Valor del percentil de la velocidad del viaje: 8.043383947939262millas/h
# 28 Valor del percentil de la velocidad del viaje: 8.152466367713004millas/h
# 30 Valor del percentil de la velocidad del viaje: 8.260869565217389millas/h
# 31 Valor del percentil de la velocidad del viaje: 8.372093023255815millas/h
# 32 Valor del percentil de la velocidad del viaje: 8.477178423236515millas/h
# 33 Valor del percentil de la velocidad del viaje: 8.583333333333332millas/h
# 34 Valor del percentil de la velocidad del viaje: 8.689655172413794millas/h
# 35 Valor del percentil de la velocidad del viaje: 8.796380090497738millas/h
# 36 Valor del percentil de la velocidad del viaje: 8.901818181818184millas/h
# 37 Valor del percentil de la velocidad del viaje: 9.000000000000002millas/h
# 38 Valor del percentil de la velocidad del viaje: 9.11392405063291millas/h
# 39 Valor del percentil de la velocidad del viaje: 9.219512195121952millas/h
# 40 Valor del percentil de la velocidad del viaje: 9.32642487046632millas/h
# 41 Valor del percentil de la velocidad del viaje: 9.432314410480348millas/h
# 42 Valor del percentil de la velocidad del viaje: 9.539170506912441millas/h
# 43 Valor del percentil de la velocidad del viaje: 9.645680819912153millas/h
# 44 Valor del percentil de la velocidad del viaje: 9.75369458128079millas/h
# 45 Valor del percentil de la velocidad del viaje: 9.863013698630137millas/h
# 46 Valor del percentil de la velocidad del viaje: 9.96923076923077millas/h
# 47 Valor del percentil de la velocidad del viaje: 10.08millas/h
# 48 Valor del percentil de la velocidad del viaje: 10.191780821917808millas/h
# 49 Valor del percentil de la velocidad del viaje: 10.304832713754646millas/h
# 50 Valor del percentil de la velocidad del viaje: 10.418006430868166millas/h
# 51 Valor del percentil de la velocidad del viaje: 10.532374100719423millas/h
# 52 Valor del percentil de la velocidad del viaje: 10.64788732394366millas/h
# 53 Valor del percentil de la velocidad del viaje: 10.764119601328904millas/h
# 54 Valor del percentil de la velocidad del viaje: 10.88259109311741millas/h
# 55 Valor del percentil de la velocidad del viaje: 11.00377358490566millas/h
# 56 Valor del percentil de la velocidad del viaje: 11.125161716288781millas/h
# 56 Valor del percentil de la velocidad del viaje: 11.25millas/h
# 57 Valor del percentil de la velocidad del viaje: 11.374407582938385millas/h
# 59 Valor del percentil de la velocidad del viaje: 11.502958579881657millas/h
# 60 Valor del percentil de la velocidad del viaje: 11.633752244165171millas/h
# 61 Valor del percentil de la velocidad del viaje: 11.764705882352942millas/h
# 62 Valor del percentil de la velocidad del viaje: 11.900826446280991millas/h
# 63 Valor del percentil de la velocidad del viaje: 12.040133779264215millas/h
# 64 Valor del percentil de la velocidad del viaje: 12.182741116751266millas/h
# 65 Valor del percentil de la velocidad del viaje: 12.328767123287673millas/h
# 66 Valor del percentil de la velocidad del viaje: 12.479999999999999millas/h
# 67 Valor del percentil de la velocidad del viaje: 12.631578947368421millas/h
# 68 Valor del percentil de la velocidad del viaje: 12.791878172588833millas/h
# 69 Valor del percentil de la velocidad del viaje: 12.956043956043956millas/h
# 70 Valor del percentil de la velocidad del viaje: 13.124999999999998millas/h
# 71 Valor del percentil de la velocidad del viaje: 13.297297297297298millas/h
# 72 Valor del percentil de la velocidad del viaje: 13.476923076923077millas/h
# 73 Valor del percentil de la velocidad del viaje: 13.664734242482032millas/h
# 74 Valor del percentil de la velocidad del viaje: 13.857493857493857millas/h
# 75 Valor del percentil de la velocidad del viaje: 14.0625millas/h
# 76 Valor del percentil de la velocidad del viaje: 14.277620396600565millas/h
# 77 Valor del percentil de la velocidad del viaje: 14.5millas/h
# 78 Valor del percentil de la velocidad del viaje: 14.733969986357435millas/h
# 79 Valor del percentil de la velocidad del viaje: 14.982164090368608millas/h
# 80 Valor del percentil de la velocidad del viaje: 15.241935483870968millas/h
# 81 Valor del percentil de la velocidad del viaje: 15.518796992481201millas/h
# 82 Valor del percentil de la velocidad del viaje: 15.813084112149532millas/h
# 83 Valor del percentil de la velocidad del viaje: 16.130346232179225millas/h
# 84 Valor del percentil de la velocidad del viaje: 16.47058823529412millas/h
# 85 Valor del percentil de la velocidad del viaje: 16.84059014033825millas/h
# 86 Valor del percentil de la velocidad del viaje: 17.23756906077348millas/h
# 87 Valor del percentil de la velocidad del viaje: 17.677611940298508millas/h
# 88 Valor del percentil de la velocidad del viaje: 18.16300129366106millas/h
# 89 Valor del percentil de la velocidad del viaje: 18.7012987012987millas/h
# 90 Valor del percentil de la velocidad del viaje: 19.307262569832403millas/h
# 91 Valor del percentil de la velocidad del viaje: 20.0millas/h
# 92 Valor del percentil de la velocidad del viaje: 20.788732394366196millas/h
# 93 Valor del percentil de la velocidad del viaje: 21.704781704781702millas/h
# 94 Valor del percentil de la velocidad del viaje: 22.773911295608436millas/h
# 95 Valor del percentil de la velocidad del viaje: 24.037715098786077millas/h
# 96 Valor del percentil de la velocidad del viaje: 25.562130177514796millas/h
# 97 Valor del percentil de la velocidad del viaje: 27.45954403117142millas/h
# 98 Valor del percentil de la velocidad del viaje: 30.011991407965645millas/h
# 99 Valor del percentil de la velocidad del viaje: 34.04888416578108millas/h
# 100 Valor del percentil de la velocidad del viaje: 127026120.6818182millas/h

# %% [markdown]
# **20. Dentro del dataset, se aplica un filtro según lo analizado anteriormente**

# %%
dy3_new = dy3_new[(dy3_new.Velocidad>0) & (dy3_new.Velocidad<45)]

# %% [markdown]
# **21. Plot para ver el cambio una vez realizado el filtro**

# %%
fig = plt.figure(figsize = (10,6))
ax = sns.boxplot("Velocidad", data = dy3_new, orient = "v")

plt.tick_params(labelsize = 20)
plt.ylabel("Velocidad(Millas/hr)", fontsize = 20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="718.8889079329414">

# %% [markdown]
# **22. Se realiza un cálculo para obtener la velocidad media de los taxis.**

# %%
Velocidad_media = sum(dy3_new.Velocidad)/len(dy3_new.Velocidad)
print("Velocidad media de los Taxis en NYC = "+str(Velocidad_media))
# Out:
# Velocidad media de los Taxis en NYC = 11.730527793967749

# %% [markdown]
# **23. Los taxis pueden viajar aproximadamente 2 millas en 10 minutos de media.**

# %%
dy3_new.head()
# Out:
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                1            1.2        -73.990211        40.750969
# 1                1            3.2        -73.935188        40.800720
# 2                1            1.1        -73.963753        40.767937
# 3                1            0.8        -73.997177        40.742168
# 4                1            2.7        -74.006844        40.730267
#
#    dropoff_longitude  dropoff_latitude  total_amount  Duracion_viaje  \
# 0         -73.987892         40.738037          7.80        7.400000
# 1         -73.952553         40.765373         12.30       12.866667
# 2         -73.956947         40.780270          8.80        9.933333
# 3         -74.008064         40.739281          7.80        6.633333
# 4         -73.976860         40.750671         16.55       17.083333
#
#     pickup_time  Velocidad
# 0  1.425629e+09   9.729730
# 1  1.425629e+09  14.922280
# 2  1.425629e+09   6.644295
# 3  1.425629e+09   7.236181
# 4  1.425629e+09   9.482927

# %% [markdown]
# **24. Plot con la librería seaborn, de la duración del viaje. Esto nos sirve para una primera inspección de los valores.**

# %%
fig = plt.figure(figsize = (10,6))
ax = sns.boxplot("trip_distance", data = dy3_new, orient = "v")

plt.tick_params(labelsize = 20)
plt.ylabel("trip Distance(Millas)", fontsize = 20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="718.8889079329414">

# %% [markdown]
# **25. Definimos una variable con el fin de  mostrar los valores contenido en los cuántiles.**

# %%
quantile_tripDistance = dy3_new.trip_distance.quantile(np.round(np.arange(0.00, 1.01, 0.01), 2))

# %% [markdown]
# **26. Cuántiles de la distancia del viaje. Se observa que no hay distancias negativas y que el percentil 100 es demasiado mayor para ser real.**

# %%
qValues = np.round(np.arange(0.01, 1.01, 0.01), 2)
for i in qValues:
    print("{} Valor del percentil de la distancia del viaje: {}millas".format((int(i*100)), quantile_tripDistance[i]))
# Out:
# 1 Valor del percentil de la distancia del viaje: 0.4millas
# 2 Valor del percentil de la distancia del viaje: 0.5millas
# 3 Valor del percentil de la distancia del viaje: 0.52millas
# 4 Valor del percentil de la distancia del viaje: 0.6millas
# 5 Valor del percentil de la distancia del viaje: 0.6millas
# 6 Valor del percentil de la distancia del viaje: 0.64millas
# 7 Valor del percentil de la distancia del viaje: 0.69millas
# 8 Valor del percentil de la distancia del viaje: 0.7millas
# 9 Valor del percentil de la distancia del viaje: 0.7millas
# 10 Valor del percentil de la distancia del viaje: 0.75millas
# 11 Valor del percentil de la distancia del viaje: 0.8millas
# 12 Valor del percentil de la distancia del viaje: 0.8millas
# 13 Valor del percentil de la distancia del viaje: 0.8millas
# 14 Valor del percentil de la distancia del viaje: 0.8399999999999999millas
# 15 Valor del percentil de la distancia del viaje: 0.89millas
# 16 Valor del percentil de la distancia del viaje: 0.9000000000000001millas
# 17 Valor del percentil de la distancia del viaje: 0.9millas
# 18 Valor del percentil de la distancia del viaje: 0.92millas
# 19 Valor del percentil de la distancia del viaje: 0.97millas
# 20 Valor del percentil de la distancia del viaje: 1.0millas
# 21 Valor del percentil de la distancia del viaje: 1.0millas
# 22 Valor del percentil de la distancia del viaje: 1.01millas
# 23 Valor del percentil de la distancia del viaje: 1.05millas
# 24 Valor del percentil de la distancia del viaje: 1.09millas
# 25 Valor del percentil de la distancia del viaje: 1.1millas
# 26 Valor del percentil de la distancia del viaje: 1.1millas
# 27 Valor del percentil de la distancia del viaje: 1.13millas
# 28 Valor del percentil de la distancia del viaje: 1.18millas
# 28 Valor del percentil de la distancia del viaje: 1.2millas
# 30 Valor del percentil de la distancia del viaje: 1.2millas
# 31 Valor del percentil de la distancia del viaje: 1.23millas
# 32 Valor del percentil de la distancia del viaje: 1.28millas
# 33 Valor del percentil de la distancia del viaje: 1.3millas
# 34 Valor del percentil de la distancia del viaje: 1.3millas
# 35 Valor del percentil de la distancia del viaje: 1.33millas
# 36 Valor del percentil de la distancia del viaje: 1.39millas
# 37 Valor del percentil de la distancia del viaje: 1.4millas
# 38 Valor del percentil de la distancia del viaje: 1.4millas
# 39 Valor del percentil de la distancia del viaje: 1.45millas
# 40 Valor del percentil de la distancia del viaje: 1.5millas
# 41 Valor del percentil de la distancia del viaje: 1.5millas
# 42 Valor del percentil de la distancia del viaje: 1.53millas
# 43 Valor del percentil de la distancia del viaje: 1.5899999999999999millas
# 44 Valor del percentil de la distancia del viaje: 1.6millas
# 45 Valor del percentil de la distancia del viaje: 1.61millas
# 46 Valor del percentil de la distancia del viaje: 1.67millas
# 47 Valor del percentil de la distancia del viaje: 1.7millas
# 48 Valor del percentil de la distancia del viaje: 1.71millas
# 49 Valor del percentil de la distancia del viaje: 1.7800000000000002millas
# 50 Valor del percentil de la distancia del viaje: 1.8millas
# 51 Valor del percentil de la distancia del viaje: 1.8199999999999998millas
# 52 Valor del percentil de la distancia del viaje: 1.8900000000000001millas
# 53 Valor del percentil de la distancia del viaje: 1.9millas
# 54 Valor del percentil de la distancia del viaje: 1.95millas
# 55 Valor del percentil de la distancia del viaje: 2.0millas
# 56 Valor del percentil de la distancia del viaje: 2.02millas
# 56 Valor del percentil de la distancia del viaje: 2.1millas
# 57 Valor del percentil de la distancia del viaje: 2.1millas
# 59 Valor del percentil de la distancia del viaje: 2.19millas
# 60 Valor del percentil de la distancia del viaje: 2.2millas
# 61 Valor del percentil de la distancia del viaje: 2.29millas
# 62 Valor del percentil de la distancia del viaje: 2.3millas
# 63 Valor del percentil de la distancia del viaje: 2.4millas
# 64 Valor del percentil de la distancia del viaje: 2.42millas
# 65 Valor del percentil de la distancia del viaje: 2.5millas
# 66 Valor del percentil de la distancia del viaje: 2.56millas
# 67 Valor del percentil de la distancia del viaje: 2.6millas
# 68 Valor del percentil de la distancia del viaje: 2.7millas
# 69 Valor del percentil de la distancia del viaje: 2.77millas
# 70 Valor del percentil de la distancia del viaje: 2.83millas
# 71 Valor del percentil de la distancia del viaje: 2.9millas
# 72 Valor del percentil de la distancia del viaje: 3.0millas
# 73 Valor del percentil de la distancia del viaje: 3.1millas
# 74 Valor del percentil de la distancia del viaje: 3.2millas
# 75 Valor del percentil de la distancia del viaje: 3.3millas
# 76 Valor del percentil de la distancia del viaje: 3.4millas
# 77 Valor del percentil de la distancia del viaje: 3.5millas
# 78 Valor del percentil de la distancia del viaje: 3.62millas
# 79 Valor del percentil de la distancia del viaje: 3.79millas
# 80 Valor del percentil de la distancia del viaje: 3.9000000000000004millas
# 81 Valor del percentil de la distancia del viaje: 4.1millas
# 82 Valor del percentil de la distancia del viaje: 4.26millas
# 83 Valor del percentil de la distancia del viaje: 4.45millas
# 84 Valor del percentil de la distancia del viaje: 4.68millas
# 85 Valor del percentil de la distancia del viaje: 4.9millas
# 86 Valor del percentil de la distancia del viaje: 5.19millas
# 87 Valor del percentil de la distancia del viaje: 5.49millas
# 88 Valor del percentil de la distancia del viaje: 5.8millas
# 89 Valor del percentil de la distancia del viaje: 6.22millas
# 90 Valor del percentil de la distancia del viaje: 6.699999999999999millas
# 91 Valor del percentil de la distancia del viaje: 7.33millas
# 92 Valor del percentil de la distancia del viaje: 8.1millas
# 93 Valor del percentil de la distancia del viaje: 8.84millas
# 94 Valor del percentil de la distancia del viaje: 9.6millas
# 95 Valor del percentil de la distancia del viaje: 10.4millas
# 96 Valor del percentil de la distancia del viaje: 11.4millas
# 97 Valor del percentil de la distancia del viaje: 13.31millas
# 98 Valor del percentil de la distancia del viaje: 16.8millas
# 99 Valor del percentil de la distancia del viaje: 18.4millas
# 100 Valor del percentil de la distancia del viaje: 235.09millas

# %% [markdown]
# **27. Dentro del dataset, se aplica un filtro según lo analizado anteriormente**

# %%
dy3_new = dy3_new[(dy3_new.trip_distance>0) & (dy3_new.trip_distance<20)]

# %% [markdown]
# **28. Plot para ver el cambio una vez realizado el filtro**

# %%
fig = plt.figure(figsize = (10,6))
ax = sns.boxplot("trip_distance", data = dy3_new, orient = "v")

plt.tick_params(labelsize = 20)
plt.ylabel("Trip Distance(Millas)", fontsize = 20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="718.8889079329414">

# %% [markdown]
# **29. Plot con la librería seaborn, el precio del viaje. Esto nos sirve para una primera inspección de los valores.**

# %%
fig = plt.figure(figsize = (10,6))
ax = sns.boxplot("total_amount", data = dy3_new, orient = "v")

plt.tick_params(labelsize = 20)
plt.ylabel("Precio del viaje", fontsize = 20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="718.8889079329414">

# %% [markdown]
# **30. Definimos una variable con el fin de  mostrar los valores contenido en los cuántiles.**

# %%
quantile_totalAmount = dy3_new.total_amount.quantile(np.round(np.arange(0.00, 1.01, 0.01), 2))

# %% [markdown]
# **31. Cuántiles del precio del viaje. Se observa que no hay precios negativos y que el percentil 100 es demasiado mayor para ser real.**

# %%
qValues = np.round(np.arange(0.01, 1.01, 0.01), 2)
for i in qValues:
    print("{} Valor del percentil del precio total del viaje: {}$".format((int(i*100)), quantile_totalAmount[i]))
# Out:
# 1 Valor del percentil del precio total del viaje: 5.3$
# 2 Valor del percentil del precio total del viaje: 5.8$
# 3 Valor del percentil del precio total del viaje: 6.3$
# 4 Valor del percentil del precio total del viaje: 6.299999999999999$
# 5 Valor del percentil del precio total del viaje: 6.3$
# 6 Valor del percentil del precio total del viaje: 6.799999999999999$
# 7 Valor del percentil del precio total del viaje: 6.8$
# 8 Valor del percentil del precio total del viaje: 6.8$
# 9 Valor del percentil del precio total del viaje: 6.96$
# 10 Valor del percentil del precio total del viaje: 7.3$
# 11 Valor del percentil del precio total del viaje: 7.3$
# 12 Valor del percentil del precio total del viaje: 7.299999999999999$
# 13 Valor del percentil del precio total del viaje: 7.55$
# 14 Valor del percentil del precio total del viaje: 7.8$
# 15 Valor del percentil del precio total del viaje: 7.8$
# 16 Valor del percentil del precio total del viaje: 7.8$
# 17 Valor del percentil del precio total del viaje: 7.880000000000001$
# 18 Valor del percentil del precio total del viaje: 8.16$
# 19 Valor del percentil del precio total del viaje: 8.3$
# 20 Valor del percentil del precio total del viaje: 8.3$
# 21 Valor del percentil del precio total del viaje: 8.3$
# 22 Valor del percentil del precio total del viaje: 8.55$
# 23 Valor del percentil del precio total del viaje: 8.76$
# 24 Valor del percentil del precio total del viaje: 8.8$
# 25 Valor del percentil del precio total del viaje: 8.8$
# 26 Valor del percentil del precio total del viaje: 8.8$
# 27 Valor del percentil del precio total del viaje: 9.3$
# 28 Valor del percentil del precio total del viaje: 9.3$
# 28 Valor del percentil del precio total del viaje: 9.3$
# 30 Valor del percentil del precio total del viaje: 9.36$
# 31 Valor del percentil del precio total del viaje: 9.45$
# 32 Valor del percentil del precio total del viaje: 9.8$
# 33 Valor del percentil del precio total del viaje: 9.8$
# 34 Valor del percentil del precio total del viaje: 9.95$
# 35 Valor del percentil del precio total del viaje: 9.96$
# 36 Valor del percentil del precio total del viaje: 10.3$
# 37 Valor del percentil del precio total del viaje: 10.3$
# 38 Valor del percentil del precio total del viaje: 10.3$
# 39 Valor del percentil del precio total del viaje: 10.56$
# 40 Valor del percentil del precio total del viaje: 10.79$
# 41 Valor del percentil del precio total del viaje: 10.8$
# 42 Valor del percentil del precio total del viaje: 10.8$
# 43 Valor del percentil del precio total del viaje: 11.15$
# 44 Valor del percentil del precio total del viaje: 11.16$
# 45 Valor del percentil del precio total del viaje: 11.3$
# 46 Valor del percentil del precio total del viaje: 11.44$
# 47 Valor del percentil del precio total del viaje: 11.76$
# 48 Valor del percentil del precio total del viaje: 11.8$
# 49 Valor del percentil del precio total del viaje: 11.8$
# 50 Valor del percentil del precio total del viaje: 12.25$
# 51 Valor del percentil del precio total del viaje: 12.3$
# 52 Valor del percentil del precio total del viaje: 12.35$
# 53 Valor del percentil del precio total del viaje: 12.36$
# 54 Valor del percentil del precio total del viaje: 12.8$
# 55 Valor del percentil del precio total del viaje: 12.88$
# 56 Valor del percentil del precio total del viaje: 12.96$
# 56 Valor del percentil del precio total del viaje: 13.3$
# 57 Valor del percentil del precio total del viaje: 13.5$
# 59 Valor del percentil del precio total del viaje: 13.56$
# 60 Valor del percentil del precio total del viaje: 13.8$
# 61 Valor del percentil del precio total del viaje: 14.12$
# 62 Valor del percentil del precio total del viaje: 14.16$
# 63 Valor del percentil del precio total del viaje: 14.3$
# 64 Valor del percentil del precio total del viaje: 14.76$
# 65 Valor del percentil del precio total del viaje: 14.8$
# 66 Valor del percentil del precio total del viaje: 15.3$
# 67 Valor del percentil del precio total del viaje: 15.35$
# 68 Valor del percentil del precio total del viaje: 15.8$
# 69 Valor del percentil del precio total del viaje: 15.95$
# 70 Valor del percentil del precio total del viaje: 16.3$
# 71 Valor del percentil del precio total del viaje: 16.55$
# 72 Valor del percentil del precio total del viaje: 16.8$
# 73 Valor del percentil del precio total del viaje: 17.16$
# 74 Valor del percentil del precio total del viaje: 17.3$
# 75 Valor del percentil del precio total del viaje: 17.8$
# 76 Valor del percentil del precio total del viaje: 18.3$
# 77 Valor del percentil del precio total del viaje: 18.5$
# 78 Valor del percentil del precio total del viaje: 18.96$
# 79 Valor del percentil del precio total del viaje: 19.34$
# 80 Valor del percentil del precio total del viaje: 19.8$
# 81 Valor del percentil del precio total del viaje: 20.3$
# 82 Valor del percentil del precio total del viaje: 20.8$
# 83 Valor del percentil del precio total del viaje: 21.62$
# 84 Valor del percentil del precio total del viaje: 22.3$
# 85 Valor del percentil del precio total del viaje: 23.15$
# 86 Valor del percentil del precio total del viaje: 23.8$
# 87 Valor del percentil del precio total del viaje: 24.8$
# 88 Valor del percentil del precio total del viaje: 25.8$
# 89 Valor del percentil del precio total del viaje: 26.8$
# 90 Valor del percentil del precio total del viaje: 28.5$
# 91 Valor del percentil del precio total del viaje: 30.3$
# 92 Valor del percentil del precio total del viaje: 32.3$
# 93 Valor del percentil del precio total del viaje: 35.13$
# 94 Valor del percentil del precio total del viaje: 38.13$
# 95 Valor del percentil del precio total del viaje: 41.3$
# 96 Valor del percentil del precio total del viaje: 45.16$
# 97 Valor del percentil del precio total del viaje: 50.3$
# 98 Valor del percentil del precio total del viaje: 58.129999999999995$
# 99 Valor del percentil del precio total del viaje: 66.13$
# 100 Valor del percentil del precio total del viaje: 548463.35$

# %% [markdown]
# **32. Dentro del dataset, se aplica un filtro según lo analizado anteriormente**

# %%
dy3_new = dy3_new[(dy3_new.total_amount>0) & (dy3_new.total_amount<67)]

# %% [markdown]
# **33. Filtro de las longitudes y latitudes de pickup**

# %%
dy3_new = dy3_new[(((dy3_new.pickup_latitude >= 40.5774) & (dy3_new.pickup_latitude <= 40.9176)) & ((dy3_new.pickup_longitude >= -74.15) & (dy3_new.pickup_longitude <= -73.7004)))]

# %% [markdown]
# **34. Filtro de longitudes y latitudes de dropoff**

# %%
dy3_new = dy3_new[(((dy3_new.dropoff_latitude >= 40.5774) & (dy3_new.dropoff_latitude <= 40.9176)) & ((dy3_new.dropoff_longitude >= -74.15) & (dy3_new.dropoff_longitude <= -73.7004)))]

# %% [markdown]
# **35. Se crean dos funciones. Una para la mínima distancia y la otra para la creación de las regiones. El parámetro de mínima distancia es tuneable, es el requerimiento que le damos para la creación de los clusteres.**

# %%
coord = dy3_new[["pickup_latitude", "pickup_longitude"]].values
neighbors = []

def min_distance(regionCenters, totalClusters):
    good_points = 0
    bad_points = 0
    less_dist = []
    more_dist = []
    min_distance = 100000  
    for i in range(totalClusters):
        good_points = 0
        bad_points = 0
        for j in range(totalClusters):
            if j != i:
                distance = gpxpy.geo.haversine_distance(latitude_1 = regionCenters[i][0], longitude_1 = regionCenters[i][1], latitude_2 = regionCenters[j][0], longitude_2 = regionCenters[j][1])
                
                distance = distance/(1.60934*1000)
                min_distance = min(min_distance, distance) 
                if distance < 2:
                    good_points += 1
                else:
                    bad_points += 1
        less_dist.append(good_points)
        more_dist.append(bad_points)
            
def makingRegions(noOfRegions):
    regions = MiniBatchKMeans(n_clusters = noOfRegions, batch_size = 10000).fit(coord)
    regionCenters = regions.cluster_centers_ 
    totalClusters = len(regionCenters)
    return regionCenters, totalClusters

# %% [markdown]
# **36. Ejecución del código anterior**

# %%
startTime = datetime.now()
for i in range(10, 100, 10):
    regionCenters, totalClusters = makingRegions(i)
    min_distance(regionCenters, totalClusters)
print("Time = "+str(datetime.now() - startTime))
# Out:
# Time = 0:02:27.229478

# %% [markdown]
# **37. Definición de variables para la posterior visualización de los resultados**

# %%
coord = dy3_new[["pickup_latitude", "pickup_longitude"]].values
regions = MiniBatchKMeans(n_clusters = 20, batch_size = 10000).fit(coord)
dy3_new["Pickup_cluster"] = regions.predict(dy3_new[["pickup_latitude", "pickup_longitude"]])

# %% [markdown]
# **38. En esta visualización se ven los centros de los clusters que se han creado.**

# %%
centerOfRegions = regions.cluster_centers_
noOfClusters = len(centerOfRegions)
m = folium.Map(location = [40.9176, -73.7004], tiles = "OpenStreetMap")

for i in range(noOfClusters):
    folium.Marker([centerOfRegions[i][0], centerOfRegions[i][1]], popup = (str(np.round(centerOfRegions[i][0], 2))+", "+str(np.round(centerOfRegions[i][1], 2)))).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **39. En esta visualización se aprecian las regiones que hemos creado para el área de NYC. Hay un total de 20 regiones, parámetro que también se puede tunear.**

# %%
NYC_latitude_range = (40.5774, 40.9176)
NYC_Longitude_range = (-74.15, -73.7004)
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1.5])
ax.scatter(x = dy3_new.pickup_longitude.values[:70000], y = dy3_new.pickup_latitude.values[:70000], c = dy3_new.Pickup_cluster.values[:70000], cmap = "Paired", s = 5)
ax.set_xlim(-74.10, -73.72)
ax.set_ylim(40.5774, 40.9176)
ax.set_title("Yellow Taxis Clustering de New York City")
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="431.1111225316557">
